# %% [markdown]
# Remember that numpy has a random number generator built in too. It has a built in seed if we want a random call to be the same every time.

# %%
import numpy as np 
np.random.seed(2007)
np.random.rand()
# Out:
# 0.6435719412889737
